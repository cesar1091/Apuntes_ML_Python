# %% [markdown]
# # Funciones de distribución de probabilidades
#
# ## Distribución Uniforme

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = 1
b = 100
n = 100000
data = np.random.uniform(a,b,n)

# %%
plt.hist(data)
# Out:
# (array([10026.,  9975., 10177.,  9968.,  9985., 10080.,  9938.,  9981.,
#         10044.,  9826.]),
#  array([ 1.0003109 , 10.90027155, 20.80023221, 30.70019287, 40.60015353,
#         50.50011419, 60.40007484, 70.3000355 , 80.19999616, 90.09995682,
#         99.99991748]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Distribución Normal

# %%
data = np.random.randn(100000)

# %%
x = range(1,100001)
plt.plot(x,data)

# %%
plt.hist(data)
# Out:
# (array([6.0000e+00, 2.8600e+02, 3.4430e+03, 1.5640e+04, 3.2813e+04,
#         3.1258e+04, 1.3597e+04, 2.7070e+03, 2.4100e+02, 9.0000e+00]),
#  array([-4.55542865, -3.63346217, -2.71149568, -1.7895292 , -0.86756271,
#          0.05440377,  0.97637025,  1.89833674,  2.82030322,  3.74226971,
#          4.66423619]),
#  <a list of 10 Patch objects>)

# %%
plt.plot(x,sorted(data))

# %%
mu = 5.5
sd = 2.75
data = 5.5 + 2.75*np.random.randn(10000)
plt.hist(data)
# Out:
# (array([  14.,   92.,  544., 1723., 2943., 2792., 1456.,  386.,   45.,
#            5.]),
#  array([-5.36962314, -3.14126692, -0.9129107 ,  1.31544552,  3.54380174,
#          5.77215796,  8.00051418, 10.22887039, 12.45722661, 14.68558283,
#         16.91393905]),
#  <a list of 10 Patch objects>)

# %%
data = np.random.randn(2,5)
data
# Out:
# array([[ 1.30326446, -0.36949426,  0.01972709,  0.78029539,  0.85873779],
#        [-0.57918414,  0.59767165, -1.06335447,  1.01492777,  0.75272358]])

# %% [markdown]
# ## La simulación de Monte Carlo

# %% [markdown]
# * Generamos 2 nros aleatorios x e y, entre 0 y 1
# * Calculamos $x^2+y^2$
#     * Si el valor es inferior a 1 --> estamos dentro del circulo
#     * Si el valor es superior a 1 --> estamos fuera del circulo
# * Calculamos el número total de veces que estan dentro del circulo y lo dividimos entre el nro total de intentos para obtener una aproximación de la probabilidad de caer dentro del circulo
# * Usamos dicha probabilidad para aproximar el valor de $\pi$
# * Repetimos el experimento un número suficientes de veces
# * Calculamos el promedio de los experimentos anteriores para dar un valor final de $\pi$

# %%
def pi_montecarlo(n, n_exp):
    pi_avg = 0
    pi_value_list = []
    for i in range(n_exp):
        value = 0
        x = np.random.uniform(0,1,n).tolist()
        y = np.random.uniform(0,1,n).tolist()
        for j in range(n):
            z = np.sqrt(x[j]*x[j] + y[j]*y[j])
            if z<=1:
                value += 1
        float_value = float(value)
        pi_value = float_value * 4 / n
        pi_value_list.append(pi_value)
        pi_avg += pi_value
    pi = pi_avg/100

    print(pi)
    fig = plt.plot(pi_value_list)
    return (pi, fig)

# %%
pi_montecarlo(100000,300)
# Out:
# 3.1416844000000013
# (3.1416844000000013, [<matplotlib.lines.Line2D at 0x1d1c8de2988>])

# %% [markdown]
# # Dummy Data Sets

# %%
import pandas as pd

# %%
data = pd.DataFrame(
    {
        'A': np.random.randn(1000),
        'B': 1.5 + 2.5*np.random.randn(1000),
        'C': np.random.uniform(5,32,1000)
    }
)

# %%
data.head()
# Out:
#           A         B          C
# 0 -0.029365  0.555465   9.452652
# 1  1.330913  3.510832  22.535735
# 2 -0.614930 -1.894892  27.619207
# 3 -0.104182  1.249873  17.280064
# 4  1.194608  2.618708  30.334206

# %%
data.describe()
# Out:
#                  A            B            C
# count  1000.000000  1000.000000  1000.000000
# mean     -0.058286     1.537287    18.127038
# std       1.006566     2.439907     7.908541
# min      -3.614980    -8.462347     5.024810
# 25%      -0.711681    -0.063650    11.093729
# 50%      -0.045331     1.479663    17.824024
# 75%       0.614180     3.284381    24.909444
# max       2.978310     7.822972    31.981983

# %%
for fila in data.columns.values:
    plt.hist(data[fila])
    plt.title(fila)
    plt.show()

# %%
data = pd.read_csv("../datasets/customer-churn-model/Customer Churn Model.txt")
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# ...

# %%
column_names = data.columns.values.tolist()

# %%
a = len(column_names)
a
# Out:
# 21

# %%
new_data = pd.DataFrame(
    {
        'Column Name': column_names,
        'A' : np.random.randn(a),
        'B' : np.random.uniform(0,1,a)     
        
    }, index =range(42,42+a)
)

# %%
new_data
# Out:
#        Column Name         A         B
# 42           State  0.075144  0.253047
# 43  Account Length -2.575918  0.623590
# 44       Area Code  0.107874  0.646116
# 45           Phone -1.641012  0.536374
# 46      Int'l Plan  0.101402  0.591081
# 47      VMail Plan  0.861266  0.173373
# 48   VMail Message -2.055100  0.326723
# 49        Day Mins -0.776429  0.966880
# 50       Day Calls  1.933042  0.346859
# 51      Day Charge -0.594136  0.253205
# 52        Eve Mins  0.404411  0.473720
# 53       Eve Calls  1.496240  0.565500
# 54      Eve Charge -1.724331  0.045748
# 55      Night Mins  0.252625  0.417606
# 56     Night Calls  0.656012  0.068256
# 57    Night Charge -1.941756  0.278763
# 58       Intl Mins -1.772042  0.779811
# 59      Intl Calls  0.265813  0.389616
# 60     Intl Charge -0.394545  0.221706
# 61  CustServ Calls  0.678240  0.808459
# 62          Churn?  0.720297  0.435376
